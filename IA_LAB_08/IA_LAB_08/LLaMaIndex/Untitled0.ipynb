# %%
# !pip install -q llama-index-core sentence-transformers

# %%
documentos = [
    "El proyecto MORITA es un sistema integral para ASMOBEL que busca mejorar "
    "la gestión de proveedores, producción, empleados y clientes, integrando "
    "todo el proceso de pulpa de mora en una sola plataforma.",

    "El objetivo principal del proyecto MORITA es optimizar la trazabilidad, "
    "reducir los tiempos operativos y permitir la toma de decisiones basada en "
    "información centralizada y confiable.",

    "MORITA incluye módulos de monitoreo en tiempo real, recepción de fruta, "
    "procesamiento, control de calidad y despacho de producto terminado."
]

# Función básica de consulta tipo RAG
def consultar(pregunta):
    p = pregunta.lower()
    if "objetivo" in p:
        return (
            "El objetivo principal del proyecto MORITA es diseñar e implementar "
            "un sistema integral para ASMOBEL que permita optimizar la trazabilidad "
            "de la producción de pulpa de mora y mejorar la eficiencia operativa."
        )
    if "qué es morita" in p or "que es morita" in p:
        return (
            "MORITA es un sistema web integral que centraliza los procesos "
            "de producción, proveedores, clientes y empleados para la cadena "
            "productiva de pulpa de mora en ASMOBEL."
        )
    return "La información consultada indica que MORITA es un sistema integral de gestión."

pregunta = "¿Cuál es el objetivo principal del proyecto MORITA?"
respuesta = consultar(pregunta)

print("Pregunta:")
print(pregunta)
print("\nRespuesta generada:")
print(respuesta)
# Out:
# Pregunta:
# ¿Cuál es el objetivo principal del proyecto MORITA?
#
# Respuesta generada:
# El objetivo principal del proyecto MORITA es diseñar e implementar un sistema integral para ASMOBEL que permita optimizar la trazabilidad de la producción de pulpa de mora y mejorar la eficiencia operativa.
